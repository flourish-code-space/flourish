# %%
import os
import sys

import django

sys.path.append('../')  # add path to project root dir

os.environ["DJANGO_SETTINGS_MODULE"] = "flourish.settings"

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

django.setup()
# Out:
#   * Reading config from flourish.ini
# Loading Data Encryption (init)...
#  * loading keys from /Users/nimrodmunatsi/source/flourish-code-space/flourish/crypto_fields
#  * loading rsa.restricted.public ... Done.
#  * loading rsa.restricted.private ... Done.
#  * loading rsa.local.public ... Done.
#  * loading rsa.local.private ... Done.
#  * loading aes.local ... Done.
#  * loading aes.restricted ... Done.
#  * loading salt.local ... Done.
#  * loading salt.restricted ... Done.
#  Done loading Data Encryption (init)...
# /Users/nimrodmunatsi/.venv/flourish/lib/python3.9/site-packages/django_q/conf.py:139: UserWarning: Retry and timeout are misconfigured. Set retry larger than timeout,
#         failure to do so will cause the tasks to be retriggered before completion.
#         See https://django-q.readthedocs.io/en/latest/configure.html#retry for details.
#   warn(
# /Users/nimrodmunatsi/.venv/flourish/lib/python3.9/site-packages/simple_history/models.py:164: UserWarning: HistoricalRecords added to abstract model (HistoryManagerMixin) without inherit=True
#   warnings.warn(msg, UserWarning)
# /Users/nimrodmunatsi/.venv/flourish/lib/python3.9/site-packages/simple_history/models.py:164: UserWarning: HistoricalRecords added to abstract model (ScheduleModelMixin) without inherit=True
#   warnings.warn(msg, UserWarning)
# /Users/nimrodmunatsi/.venv/flourish/lib/python3.9/site-packages/simple_history/models.py:164: UserWarning: HistoricalRecords added to abstract model (VisitModelMixin) without inherit=True
#   warnings.warn(msg, UserWarning)
# /Users/nimrodmunatsi/.venv/flourish/lib/python3.9/site-packages/simple_history/models.py:164: UserWarning: HistoricalRecords added to abstract model (OnScheduleModelMixin) without inherit=True
#   warnings.warn(msg, UserWarning)
# /Users/nimrodmunatsi/.venv/flourish/lib/python3.9/site-packages/simple_history/models.py:164: UserWarning: HistoricalRecords added to abstract model (OffStudyMixin) without inherit=True
#   warnings.warn(msg, UserWarning)
# /Users/nimrodmunatsi/.venv/flourish/lib/python3.9/site-packages/simple_history/models.py:164: UserWarning: HistoricalRecords added to abstract model (OnScheduleModelMixin) without inherit=True
#   warnings.warn(msg, UserWarning)
# Loading Data Encryption ...
#  * found encryption keys in /Users/nimrodmunatsi/source/flourish-code-space/flourish/crypto_fields.
#  * using model django_crypto_fields.crypt.
#  Done loading Data Encryption.
# Loading Edc Consent ...
#  * checking for site consents ...
#  * registered consents 'consents' from 'flourish_caregiver'
#  * registered consents 'consents' from 'flourish_child'
#  * registered consents 'consents' from 'pre_flourish'
#  * registered consents 'consents' from 'flourish_facet'
#  * flourish_caregiver.subjectconsent 1 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * flourish_caregiver.subjectconsent 2 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * flourish_caregiver.subjectconsent 3 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * flourish_caregiver.subjectconsent 4 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * flourish_caregiver.tbadolconsent 1 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * flourish_caregiver.tbinformedconsent 1 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * flourish_child.childdummysubjectconsent 1 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * flourish_child.childdummysubjectconsent 2 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * flourish_child.childdummysubjectconsent 2.1 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * flourish_child.childdummysubjectconsent 3 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * flourish_child.childdummysubjectconsent 4 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * flourish_facet.facetconsent 1 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * flourish_facet.motherchildconsent 1 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * pre_flourish.preflourishcaregiverchildconsent 1 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * pre_flourish.preflourishcaregiverchildconsent 4 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * pre_flourish.preflourishchilddummysubjectconsent 1 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * pre_flourish.preflourishchilddummysubjectconsent 4 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * pre_flourish.preflourishconsent 1 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * pre_flourish.preflourishconsent 4 covering 2020-07-01 UTC to 2025-06-30 UTC
#  * pre_flourish.preflourishconsent 4.1 covering 2020-07-01 UTC to 2025-06-30 UTC
#  Done loading Edc Consent.
# Loading Edc Device ...
#   * device id is '99'.
#   * device role is 'CentralServer'.
#  Done loading Edc Device.
# Loading Edc Identifier ...
#  Warning: 'identifier_prefix' has not been explicitly set. Using default '999'. See AppConfig.
#  * identifier prefix: 999
#  * check-digit modulus: 7
#  Done loading Edc Identifier
# Loading Edc Lab ...
#  * checking for labs ...
#  Done loading Edc Lab.
# Loading Edc Navbar ...
#  * checking for site navbars ...
#          * registered navbars 'navbars' from 'edc_consent'
#  * registered navbars 'navbars' from 'edc_device'
#  * registered navbars 'navbars' from 'edc_navbar'
#  * registered navbars 'navbars' from 'edc_reference'
#  * registered navbars 'navbars' from 'edc_visit_schedule'
#  * registered navbars 'navbars' from 'flourish_export'
#  * registered navbars 'navbars' from 'flourish_dashboard'
#  * registered navbars 'navbars' from 'flourish_follow'
#  * registered navbars 'navbars' from 'pre_flourish_follow'
#  * registered navbars 'navbars' from 'flourish_reports'
#  * registered navbars 'navbars' from 'edc_base'
#  * registered navbars 'navbars' from 'edc_data_manager'
#  * registered navbars 'navbars' from 'edc_odk'
#  * registered navbars 'navbars' from 'edc_protocol'
#  * registered navbars 'navbars' from 'edc_senaite_interface'
#  * registered navbars 'navbars' from 'pre_flourish'
#  * registered navbars 'navbars' from 'flourish_calendar'
#  * registered navbars 'navbars' from 'flourish'
#  * registered navbars 'navbars' from 'flourish_facet'
#  Done loading Edc Navbar.
#  * checking for site prn_forms ...
# Loading Edc Registration ...
#   * using edc_registration.registeredsubject
#  Done loading Edc Registration.
# Loading Edc Reference ...
#  * checking for reference_model_configs ...
#  * checking for labs ...
#  * registered reference model configs from application 'flourish_reference'
#  Done loading Edc Reference.
# Loading Visit Schedules ...
#  * checking site for module 'visit_schedules' ...
#  * registered visit schedule from 'flourish_visit_schedule'
#  * registered visit schedule from 'pre_flourish'
#  * registered visit schedule from 'flourish_facet'
#  Done loading Visit Schedules.
# Loading EDC Call Manager ...
#  * call models are in app edc_call_manager.
#  * checking for site model_callers ...
#  * registered model caller '<class 'flourish_follow.model_callers.model_callers.WorkListFollowUpModelCaller'>'
#  * registered model caller '<class 'pre_flourish_follow.model_callers.model_callers.PreFlourishWorkListFollowUpModelCaller'>'
#  Done loading EDC Call Manager.
# Loading edc_metadata_rules ...
#  * checking for metadata_rules ...
#    - imported metadata rules from 'flourish_metadata_rules.metadata_rules'
#    - imported metadata rules from 'pre_flourish.metadata_rules'
#    - imported metadata rules from 'flourish_facet.metadata_rules'
#  Done loading edc_metadata_rules.
# Loading Edc Appointments ...
#  * edc_appointment.appointment.
#  * pre_flourish.appointment.
#  * flourish_child.appointment.
#  * flourish_facet.appointment.
#  Done loading Edc Appointments.
# Loading Edc Base ...
#  * default TIME_ZONE Africa/Gaborone.
#  Done loading Edc Base.
# Loading Edc Facility ...
#  * 7-Day Clinic MO(100 slots), TU(100 slots), WE(100 slots), TH(100 slots), FR(100 slots), SA(100 slots), SU(100 slots).
#  * 5-Day Clinic MO(100 slots), TU(100 slots), WE(100 slots), TH(100 slots), FR(100 slots).
#  Done loading Edc Facility.
# Loading Edc Metadata ...
#  * using default metadata models from 'edc_metadata'
#  Done loading Edc Metadata.
# Loading Edc Protocol ...
#  * BHP142: Flourish.
#  * Study opening date: 2020-07-01 UTC
#  * Expected study closing date: 2025-06-30 UTC
#  Done loading Edc Protocol.
# Loading Edc Visit Tracking ...
#  * flourish_caregiver.maternalvisit uses model attr 'maternal_visit'
#  * flourish_child.childvisit uses model attr 'child_visit'
#  * pre_flourish.preflourishvisit uses model attr 'pre_flourish_visit'
#  * flourish_facet.facetvisit uses model attr 'facet_visit'
#  Done loading Edc Visit Tracking.
# Loading Edc Timepoint ...
#  * 'edc_appointment.appointment' is a timepoint model.
#  * 'edc_appointment.historicalappointment' is a timepoint model.
#  * 'pre_flourish.appointment' is a timepoint model.
#  * 'flourish_facet.appointment' is a timepoint model.
#  * 'flourish_child.appointment' is a timepoint model.
#  * 'flourish_child.historicalappointment' is a timepoint model.
#  Done loading Edc Timepoint.

# %%
from django.db.models import Count
from flourish_caregiver.models import SubjectConsent


def mothers_with_multiple_kids():
    consents = SubjectConsent.objects.annotate(
        child_count=Count('caregiverchildconsent')
    ).filter(child_count__gt=1)
    return consents.values_list('subject_identifier', flat=True)

# %%
from itertools import combinations


def find_objects_within_90_days(object_list):
    """
    Given a list of SubjectConsent objects, 
    return the first pair of objects found that have date difference within 90 days.
    If no such pair is found, return None.
    """
    for obj1, obj2 in combinations(object_list, 2):
        if abs((obj1.report_datetime - obj2.report_datetime).days) <= 90:
            return obj1, obj2
    return None

# %%
def compare_instances(instance1, instance2, exclude_fields=None):
    """
    Compare two Django model instances field by field.

    Parameters:
        instance1, instance2: The instances to compare.
        exclude_fields: A list of field names to exclude from comparison. Defaults to None.

    Returns:
        dict: A dictionary of field names and boolean values indicating whether the 
              values for that field in instance1 and instance2 are equal.
    """
    assert instance1.__class__ == instance2.__class__, "Instances must be of the same class."

    comparison_dict = {}

    field_names = [f.name for f in instance1._meta.fields]
    if exclude_fields:
        field_names = [f for f in field_names if f not in exclude_fields]

    for field in field_names:
        comparison_dict[field] = (getattr(instance1, field) == getattr(instance2, field))

    return comparison_dict

# %%
def add_to_mothers_with_different_data(mother, visit_crf_model, unique_visit_code, corresponding_visit_code):
    visit_tuple = tuple(sorted([unique_visit_code, corresponding_visit_code]))
    visit_str = f'({visit_tuple[0]}, {visit_tuple[1]})'
    if mother not in mothers_with_different_data:
        mothers_with_different_data[mother] = []
    for existing_entry in mothers_with_different_data[mother]:
        if visit_crf_model in existing_entry and existing_entry[visit_crf_model] == visit_str:
            return
    mothers_with_different_data[mother].append({visit_crf_model: visit_str})

# %%
import pytz
from tqdm import tqdm
from flourish_caregiver.models import MaternalVisit
from django.apps import apps as django_apps


mothers_with_different_data = {}
tz = pytz.timezone('Africa/Gaborone')

for mother in tqdm(mothers_with_multiple_kids()):
    unique_mother_visits_codes = list(
        set(MaternalVisit.objects.filter(subject_identifier=mother).values_list(
            'visit_code', flat=True)))
    for unique_visit_code in unique_mother_visits_codes:
        if unique_visit_code in ['2100T']:
            continue

        unique_visit = MaternalVisit.objects.filter(subject_identifier=mother,
                                                    visit_code=unique_visit_code).earliest(
            'report_datetime')
        if getattr(unique_visit, 'visits', None) is not None:
            appt = unique_visit.appointment
            visit_definition = appt.visits.get(appt.visit_code)
            ideal_timepoint = appt.timepoint_datetime

            earliest_appt_dt = (ideal_timepoint - visit_definition.rlower).astimezone(tz)
            latest_appt_dt = (ideal_timepoint + visit_definition.rupper).astimezone(tz)

            try:
                corresponding_maternal_visit = MaternalVisit.objects.filter(
                    subject_identifier=mother,
                    report_datetime__range=(earliest_appt_dt, latest_appt_dt)).exclude(
                    schedule_name=unique_visit.schedule_name).latest('report_datetime')

            except MaternalVisit.DoesNotExist:
                continue
            else:
                visit_crfs = unique_visit.visits.get(unique_visit.visit_code).crfs
                for visit_crf in visit_crfs:
                    crf_model_cls = django_apps.get_model(visit_crf.model)
                    try:
                        crf_model_objs = crf_model_cls.objects.get(
                            maternal_visit=unique_visit)
                    except crf_model_cls.DoesNotExist:
                        continue
                    try:
                        corresponding_crf_model_objs = crf_model_cls.objects.get(
                            maternal_visit=corresponding_maternal_visit
                        )
                    except crf_model_cls.DoesNotExist:
                        continue
                    exclude_fields = ['id', '_state', 'created', 'modified',
                                      'user_created', 'device_created', 'device_modified',
                                      'form_as_json', 'site', 'consent_model',
                                      'consent_version', 'maternal_visit',
                                      'report_datetime', 'user_modified',
                                      'hostname_created', 'hostname_modified', 'revision']

                    comparison_result = compare_instances(
                        crf_model_objs, corresponding_crf_model_objs,
                        exclude_fields)
                    for field, equal in comparison_result.items():
                        if not equal:
                            add_to_mothers_with_different_data(mother, visit_crf.model,
                                                               unique_visit_code, corresponding_maternal_visit.visit_code)
                            break
# Out:
# 100%|██████████| 141/141 [00:27<00:00,  5.14it/s]
# {'B142-040990669-9': [{'flourish_caregiver.sociodemographicdata': '(2002M, 3001M)'},
#   {'flourish_caregiver.covid19': '(2002M, 3001M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2001M, 3000M)'},
#   {'flourish_caregiver.covid19': '(2001M, 3000M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2003M, 3002M)'}],
#  'B142-040990529-5': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2008M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2008M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(1000M, 2008M)'}],
#  'B142-040990464-5': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2008M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2008M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(1000M, 2008M)'}],
#  'B142-040990466-0': [{'flourish_caregiver.sociodemographicdata': '(2010M, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(2010M, 3000M)'},
#   {'flourish_caregiver.sociodemographicdata': '(1000M, 2003M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2003M)'},
#   {'flourish_caregiver.covid19': '(1000M, 2003M)'}],
#  'B142-040990558-4': [{'flourish_caregiver.medicalhistory': '(1000M, 2000D)'},
#   {'flourish_caregiver.caregiverclinicalmeasurements': '(1000M, 2000D)'},
#   {'flourish_caregiver.covid19': '(1000M, 2000D)'},
#   {'flourish_caregiver.medicalhistory': '(2000D, 2001M)'},
#   {'flourish_caregiver.covid19': '(2000D, 2001M)'},
#   {'flourish_caregiver.sociodemographicdata': '(1000M, 2000M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2000M)'},
#   {'flourish_caregiver.caregiverclinicalmeasurements': '(1000M, 2000M)'},
#   {'flourish_caregiver.covid19': '(1000M, 2000M)'},
#   {'flourish_caregiver.medicalhistory': '(2006M, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(3000M, 3003M)'}],
#  'B142-040990893-5': [{'flourish_caregiver.caregiverclinicalmeasurements': '(2000M, 2100T)'}],
#  'B142-040990875-2': [{'flourish_caregiver.sociodemographicdata': '(2003M, 3005M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2000M, 3002M)'},
#   {'flourish_caregiver.medicalhistory': '(2000M, 3002M)'},
#   {'flourish_caregiver.covid19': '(2000M, 3002M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2002M, 3004M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2001M, 3003M)'}],
#  'B142-040990320-9': [{'flourish_caregiver.sociodemographicdata': '(2000M, 2001M)'},
#   {'flourish_caregiver.medicalhistory': '(2000M, 2001M)'},
#   {'flourish_caregiver.covid19': '(2000M, 2001M)'}],
#  'B142-040990502-2': [{'flourish_caregiver.sociodemographicdata': '(2007M, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(2007M, 3000M)'},
#   {'flourish_caregiver.maternalinterimidccversion2': '(2007M, 3000M)'}],
#  'B142-040990857-0': [{'flourish_caregiver.sociodemographicdata': '(2004M, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(2004M, 3000M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(2004M, 3000M)'}],
#  'R142-040990257-3': [{'flourish_caregiver.sociodemographicdata': '(2000M, 2008M)'}],
#  'B142-040990562-6': [{'flourish_caregiver.medicalhistory': '(2000D, 2005M)'},
#   {'flourish_caregiver.sociodemographicdata': '(1000M, 2005M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2005M)'},
#   {'flourish_caregiver.medicalhistory': '(2002M, 2007M)'},
#   {'flourish_caregiver.breastfeedingquestionnaire': '(2002M, 2007M)'},
#   {'flourish_caregiver.maternalarvpostadherence': '(2002M, 2007M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2001M, 2006M)'}],
#  'B142-040990520-4': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2007M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2007M)'}],
#  'B142-040991009-7': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2000M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2000M)'},
#   {'flourish_caregiver.obstericalhistory': '(1000M, 2000M)'},
#   {'flourish_caregiver.caregiverclinicalmeasurements': '(1000M, 2000M)'},
#   {'flourish_caregiver.caregivergadanxietyscreening': '(1000M, 2000M)'},
#   {'flourish_caregiver.covid19': '(1000M, 2000M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2002M, 2003M)'},
#   {'flourish_caregiver.medicalhistory': '(2002M, 2003M)'}],
#  'B142-040990593-1': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2005M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2005M)'}],
#  'B142-040990560-0': [{'flourish_caregiver.sociodemographicdata': '(1000M, 3001M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 3001M)'},
#   {'flourish_caregiver.covid19': '(1000M, 3001M)'},
#   {'flourish_caregiver.medicalhistory': '(2000D, 3002M)'}],
#  'B142-040990636-8': [{'flourish_caregiver.sociodemographicdata': '(2006M, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(2006M, 3000M)'}],
#  'B142-040990837-2': [{'flourish_caregiver.sociodemographicdata': '(2007M, 2007M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2008M, 2008M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2006M, 2006M)'}],
#  'B142-040990486-8': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2008M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2008M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(1000M, 2008M)'}],
#  'B142-040990786-1': [{'flourish_caregiver.sociodemographicdata': '(2008M, 3000C)'},
#   {'flourish_caregiver.medicalhistory': '(2008M, 3000C)'},
#   {'flourish_caregiver.sociodemographicdata': '(2000M, 2001M)'},
#   {'flourish_caregiver.medicalhistory': '(2000M, 2001M)'},
#   {'flourish_caregiver.covid19': '(2000M, 2001M)'}],
#  'B142-040990713-5': [{'flourish_caregiver.sociodemographicdata': '(2001M, 2002M)'},
#   {'flourish_caregiver.covid19': '(2001M, 2002M)'},
#   {'flourish_caregiver.medicalhistory': '(2005M, 3001M)'},
#   {'flourish_caregiver.maternalinterimidccversion2': '(2008M, 3000M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(2008M, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(2004M, 3000M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(2004M, 3000M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(3000M, 3004M)'}],
#  'B142-040990639-2': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2000M)'},
#   {'flourish_caregiver.caregiverclinicalmeasurements': '(1000M, 2000M)'},
#   {'flourish_caregiver.obstericalhistory': '(1000M, 2000M)'},
#   {'flourish_caregiver.covid19': '(1000M, 2000M)'},
#   {'flourish_caregiver.medicalhistory': '(2000D, 2001M)'},
#   {'flourish_caregiver.hivrapidtestcounseling': '(2000D, 2000M)'},
#   {'flourish_caregiver.caregiverclinicalmeasurements': '(2000D, 2000M)'},
#   {'flourish_caregiver.covid19': '(2000D, 2000M)'}],
#  'B142-040990666-5': [{'flourish_caregiver.sociodemographicdata': '(2003M, 2006M)'},
#   {'flourish_caregiver.medicalhistory': '(2003M, 2006M)'}],
#  'B142-040990357-1': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2007M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2007M)'}],
#  'B142-040990172-4': [{'flourish_caregiver.medicalhistory': '(2000D, 2005M)'},
#   {'flourish_caregiver.medicalhistory': '(3001M, 3005M)'},
#   {'flourish_caregiver.sociodemographicdata': '(3000C, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(3000C, 3000M)'},
#   {'flourish_caregiver.caregiverclinicalmeasurements': '(3000C, 3000M)'},
#   {'flourish_caregiver.caregiverphqdeprscreening': '(3000C, 3000M)'},
#   {'flourish_caregiver.caregivergadanxietyscreening': '(3000C, 3000M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(3000C, 3000M)'},
#   {'flourish_caregiver.sociodemographicdata': '(1000M, 2004M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2004M)'},
#   {'flourish_caregiver.covid19': '(1000M, 2004M)'}],
#  'B142-040990096-5': [{'flourish_caregiver.sociodemographicdata': '(3002M, 3003M)'},
#   {'flourish_caregiver.medicalhistory': '(3002M, 3003M)'}],
#  'B142-040990651-7': [{'flourish_caregiver.sociodemographicdata': '(2008M, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(2008M, 3000M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(2008M, 3000M)'}],
#  'B142-040990023-9': [{'flourish_caregiver.hivdisclosurestatusa': '(2007M, 2007M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2008M, 2009M)'}],
#  'B142-040991037-8': [{'flourish_caregiver.posthivrapidtestandconseling': '(2004M, 3000M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2004M, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(2004M, 3000M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(2004M, 3000M)'},
#   {'flourish_caregiver.sociodemographicdata': '(1000M, 3002M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 3002M)'}],
#  'R142-040990903-2': [{'flourish_caregiver.sociodemographicdata': '(2000M, 2003M)'},
#   {'flourish_caregiver.covid19': '(2000M, 2003M)'}],
#  'B142-040990099-9': [{'flourish_caregiver.relationshipfatherinvolvement': '(2008M, 2008M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2010M, 2010M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(2012M, 2012M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2011M, 2011M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2009M, 2009M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2000M, 2000M)'},
#   {'flourish_caregiver.caregiverclinicalmeasurements': '(2000M, 2000M)'}],
#  'B142-040990369-6': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2007M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2007M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2002M, 2010M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2001M, 2009M)'}],
#  'B142-040990604-6': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2007M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2001M, 2008M)'},
#   {'flourish_caregiver.posthivrapidtestandconseling': '(2009M, 3000M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2009M, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(2009M, 3000M)'}],
#  'B142-040990881-0': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2005M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2005M)'}],
#  'B142-040990120-3': [{'flourish_caregiver.covid19': '(2000D, 2005M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2003M, 2008M)'},
#   {'flourish_caregiver.covid19': '(2003M, 2008M)'},
#   {'flourish_caregiver.sociodemographicdata': '(1000M, 2004M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2004M)'},
#   {'flourish_caregiver.covid19': '(1000M, 2004M)'}],
#  'B142-040991112-9': [{'flourish_caregiver.medicalhistory': '(1000M, 2000D)'},
#   {'flourish_caregiver.caregiverclinicalmeasurements': '(1000M, 2000D)'},
#   {'flourish_caregiver.tbroutinehealthscreenv2': '(1000M, 2000D)'},
#   {'flourish_caregiver.covid19': '(1000M, 2000D)'},
#   {'flourish_caregiver.sociodemographicdata': '(2000M, 2001M)'},
#   {'flourish_caregiver.medicalhistory': '(2000M, 2001M)'},
#   {'flourish_caregiver.covid19': '(2000M, 2001M)'}],
#  'B142-040990570-9': [{'flourish_caregiver.medicalhistory': '(2000D, 2005M)'},
#   {'flourish_caregiver.sociodemographicdata': '(1000M, 2003M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2003M)'},
#   {'flourish_caregiver.covid19': '(1000M, 2003M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2001M, 2006M)'}],
#  'B142-040990992-5': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2002M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2002M)'},
#   {'flourish_caregiver.medicalhistory': '(2000D, 2004M)'}],
#  'B142-040990701-0': [{'flourish_caregiver.sociodemographicdata': '(2006M, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(2006M, 3000M)'},
#   {'flourish_caregiver.maternalinterimidccversion2': '(2006M, 3000M)'}],
#  'B142-040990044-5': [{'flourish_caregiver.sociodemographicdata': '(2002M, 2003M)'},
#   {'flourish_caregiver.covid19': '(2002M, 2003M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2006M, 2006M)'},
#   {'flourish_caregiver.medicalhistory': '(2006M, 2006M)'}],
#  'B142-040990610-3': [{'flourish_caregiver.sociodemographicdata': '(2008M, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(2008M, 3000M)'},
#   {'flourish_caregiver.maternalinterimidccversion2': '(2008M, 3000M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(2008M, 3000M)'},
#   {'flourish_caregiver.maternalarvpostadherence': '(2008M, 3000M)'}],
#  'B142-040990705-1': [{'flourish_caregiver.sociodemographicdata': '(2005M, 3002M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2004M, 3001M)'}],
#  'B142-040990645-9': [{'flourish_caregiver.posthivrapidtestandconseling': '(2008M, 3000M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2008M, 3000M)'},
#   {'flourish_caregiver.medicalhistory': '(2008M, 3000M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(2008M, 3000M)'}],
#  'B142-040990355-5': [{'flourish_caregiver.maternalinterimidccversion2': '(2002M, 3003M)'}],
#  'B142-040990528-7': [{'flourish_caregiver.sociodemographicdata': '(2000M, 2003M)'},
#   {'flourish_caregiver.medicalhistory': '(2000M, 2003M)'},
#   {'flourish_caregiver.covid19': '(2000M, 2003M)'}],
#  'B142-040990472-8': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2009M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2009M)'}],
#  'B142-040990612-9': [{'flourish_caregiver.sociodemographicdata': '(2004M, 2006M)'}],
#  'B142-040990022-1': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2007M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2007M)'},
#   {'flourish_caregiver.covid19': '(1000M, 2007M)'},
#   {'flourish_caregiver.medicalhistory': '(2000D, 2008M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2001M, 2009M)'}],
#  'B142-040990968-5': [{'flourish_caregiver.sociodemographicdata': '(2002M, 3000M)'},
#   {'flourish_caregiver.covid19': '(2002M, 3000M)'},
#   {'flourish_caregiver.sociodemographicdata': '(1000M, 3004M)'},
#   {'flourish_caregiver.relationshipfatherinvolvement': '(1000M, 3004M)'}],
#  'B142-040990682-2': [{'flourish_caregiver.posthivrapidtestandconseling': '(2007M, 3000M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2007M, 3000M)'}],
#  'R142-040990631-9': [{'flourish_caregiver.sociodemographicdata': '(2000M, 2006M)'},
#   {'flourish_caregiver.covid19': '(2000M, 2006M)'}],
#  'B142-040990128-6': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2007M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2007M)'},
#   {'flourish_caregiver.medicalhistory': '(2000D, 2008M)'},
#   {'flourish_caregiver.sociodemographicdata': '(2002M, 2010M)'}],
#  'B142-040990371-2': [{'flourish_caregiver.sociodemographicdata': '(1000M, 2010M)'},
#   {'flourish_caregiver.medicalhistory': '(1000M, 2010M)'}]}

# %%
import csv
import re


def transform_model_name(model_name):
    # Replace underscores with spaces and split by dot
    parts = model_name.replace('_', ' ').split('.')
    # Capitalize each part
    readable_parts = [part.capitalize() for part in parts]
    # Join the parts back into a single human-readable string
    return ' '.join(readable_parts)
# Out:
# {'B142-040990669-9': ['flourish_caregiver.sociodemographicdata_2002M',
#   'flourish_caregiver.covid19_2002M',
#   'flourish_caregiver.caregiverclinicalmeasurements_2100T',
#   'flourish_caregiver.sociodemographicdata_2001M',
#   'flourish_caregiver.covid19_2001M',
#   'flourish_caregiver.sociodemographicdata_3001M',
#   'flourish_caregiver.covid19_3001M',
#   'flourish_caregiver.sociodemographicdata_2003M',
#   'flourish_caregiver.sociodemographicdata_2002M',
#   'flourish_caregiver.covid19_2002M',
#   'flourish_caregiver.caregiverclinicalmeasurements_2100T',
#   'flourish_caregiver.sociodemographicdata_2001M',
#   'flourish_caregiver.covid19_2001M',
#   'flourish_caregiver.sociodemographicdata_3001M',
#   'flourish_caregiver.covid19_3001M',
#   'flourish_caregiver.sociodemographicdata_2003M'],
#  'B142-040990529-5': ['flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M',
#   'flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M'],
#  'B142-040990464-5': ['flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M',
#   'flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M'],
#  'B142-040990466-0': ['flourish_caregiver.sociodemographicdata_2010M',
#   'flourish_caregiver.medicalhistory_2010M',
#   'flourish_caregiver.sociodemographicdata_2003M',
#   'flourish_caregiver.medicalhistory_2003M',
#   'flourish_caregiver.covid19_2003M',
#   'flourish_caregiver.sociodemographicdata_2010M',
#   'flourish_caregiver.medicalhistory_2010M',
#   'flourish_caregiver.sociodemographicdata_2003M',
#   'flourish_caregiver.medicalhistory_2003M',
#   'flourish_caregiver.covid19_2003M'],
#  'B142-040990558-4': ['flourish_caregiver.medicalhistory_1000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_1000M',
#   'flourish_caregiver.covid19_1000M',
#   'flourish_caregiver.medicalhistory_2001M',
#   'flourish_caregiver.covid19_2001M',
#   'flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.medicalhistory_2000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_2000M',
#   'flourish_caregiver.covid19_2000M',
#   'flourish_caregiver.medicalhistory_2006M',
#   'flourish_caregiver.medicalhistory_3003M',
#   'flourish_caregiver.medicalhistory_1000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_1000M',
#   'flourish_caregiver.covid19_1000M',
#   'flourish_caregiver.medicalhistory_2001M',
#   'flourish_caregiver.covid19_2001M',
#   'flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.medicalhistory_2000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_2000M',
#   'flourish_caregiver.covid19_2000M',
#   'flourish_caregiver.medicalhistory_2006M',
#   'flourish_caregiver.medicalhistory_3003M',
#   'flourish_caregiver.medicalhistory_1000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_1000M',
#   'flourish_caregiver.covid19_1000M',
#   'flourish_caregiver.medicalhistory_2001M',
#   'flourish_caregiver.covid19_2001M',
#   'flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.medicalhistory_2000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_2000M',
#   'flourish_caregiver.covid19_2000M',
#   'flourish_caregiver.medicalhistory_2006M',
#   'flourish_caregiver.medicalhistory_3003M'],
#  'B142-040990893-5': ['flourish_caregiver.caregiverclinicalmeasurements_2000M'],
#  'B142-040990875-2': ['flourish_caregiver.sociodemographicdata_3005M',
#   'flourish_caregiver.sociodemographicdata_3002M',
#   'flourish_caregiver.medicalhistory_3002M',
#   'flourish_caregiver.covid19_3002M',
#   'flourish_caregiver.sociodemographicdata_2003M',
#   'flourish_caregiver.sociodemographicdata_3004M',
#   'flourish_caregiver.sociodemographicdata_3003M'],
#  'B142-040990320-9': ['flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.medicalhistory_2000M',
#   'flourish_caregiver.covid19_2000M'],
#  'B142-040990502-2': ['flourish_caregiver.sociodemographicdata_2007M',
#   'flourish_caregiver.medicalhistory_2007M',
#   'flourish_caregiver.maternalinterimidccversion2_2007M',
#   'flourish_caregiver.sociodemographicdata_2007M',
#   'flourish_caregiver.medicalhistory_2007M',
#   'flourish_caregiver.maternalinterimidccversion2_2007M'],
#  'B142-040990857-0': ['flourish_caregiver.sociodemographicdata_2004M',
#   'flourish_caregiver.medicalhistory_2004M',
#   'flourish_caregiver.relationshipfatherinvolvement_2004M',
#   'flourish_caregiver.sociodemographicdata_3000M',
#   'flourish_caregiver.medicalhistory_3000M',
#   'flourish_caregiver.relationshipfatherinvolvement_3000M',
#   'flourish_caregiver.sociodemographicdata_2004M',
#   'flourish_caregiver.medicalhistory_2004M',
#   'flourish_caregiver.relationshipfatherinvolvement_2004M',
#   'flourish_caregiver.sociodemographicdata_3000M',
#   'flourish_caregiver.medicalhistory_3000M',
#   'flourish_caregiver.relationshipfatherinvolvement_3000M'],
#  'R142-040990257-3': ['flourish_caregiver.sociodemographicdata_2008M'],
#  'B142-040990562-6': ['flourish_caregiver.medicalhistory_2005M',
#   'flourish_caregiver.sociodemographicdata_1000M',
#   'flourish_caregiver.medicalhistory_1000M',
#   'flourish_caregiver.medicalhistory_2007M',
#   'flourish_caregiver.breastfeedingquestionnaire_2007M',
#   'flourish_caregiver.maternalarvpostadherence_2007M',
#   'flourish_caregiver.sociodemographicdata_2006M'],
#  'B142-040990520-4': ['flourish_caregiver.sociodemographicdata_2007M',
#   'flourish_caregiver.medicalhistory_2007M',
#   'flourish_caregiver.sociodemographicdata_2007M',
#   'flourish_caregiver.medicalhistory_2007M'],
#  'B142-040991009-7': ['flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.medicalhistory_2000M',
#   'flourish_caregiver.obstericalhistory_2000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_2000M',
#   'flourish_caregiver.caregivergadanxietyscreening_2000M',
#   'flourish_caregiver.covid19_2000M',
#   'flourish_caregiver.sociodemographicdata_2003M',
#   'flourish_caregiver.medicalhistory_2003M',
#   'flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.medicalhistory_2000M',
#   'flourish_caregiver.obstericalhistory_2000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_2000M',
#   'flourish_caregiver.caregivergadanxietyscreening_2000M',
#   'flourish_caregiver.covid19_2000M',
#   'flourish_caregiver.sociodemographicdata_2003M',
#   'flourish_caregiver.medicalhistory_2003M'],
#  'B142-040990593-1': ['flourish_caregiver.sociodemographicdata_2005M',
#   'flourish_caregiver.medicalhistory_2005M',
#   'flourish_caregiver.sociodemographicdata_2005M',
#   'flourish_caregiver.medicalhistory_2005M'],
#  'B142-040990560-0': ['flourish_caregiver.sociodemographicdata_1000M',
#   'flourish_caregiver.medicalhistory_1000M',
#   'flourish_caregiver.covid19_1000M',
#   'flourish_caregiver.sociodemographicdata_3001M',
#   'flourish_caregiver.medicalhistory_3001M',
#   'flourish_caregiver.covid19_3001M',
#   'flourish_caregiver.medicalhistory_3002M'],
#  'B142-040990636-8': ['flourish_caregiver.sociodemographicdata_2006M',
#   'flourish_caregiver.medicalhistory_2006M'],
#  'B142-040990837-2': ['flourish_caregiver.sociodemographicdata_2007M',
#   'flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.sociodemographicdata_2006M'],
#  'B142-040990486-8': ['flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M',
#   'flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M'],
#  'B142-040990786-1': ['flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.medicalhistory_2000M',
#   'flourish_caregiver.covid19_2000M',
#   'flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.medicalhistory_2000M',
#   'flourish_caregiver.covid19_2000M'],
#  'B142-040990713-5': ['flourish_caregiver.sociodemographicdata_2002M',
#   'flourish_caregiver.covid19_2002M',
#   'flourish_caregiver.medicalhistory_2005M',
#   'flourish_caregiver.maternalinterimidccversion2_2008M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M',
#   'flourish_caregiver.sociodemographicdata_2001M',
#   'flourish_caregiver.covid19_2001M',
#   'flourish_caregiver.medicalhistory_2004M',
#   'flourish_caregiver.relationshipfatherinvolvement_2004M',
#   'flourish_caregiver.relationshipfatherinvolvement_3004M',
#   'flourish_caregiver.sociodemographicdata_2002M',
#   'flourish_caregiver.covid19_2002M',
#   'flourish_caregiver.medicalhistory_2005M',
#   'flourish_caregiver.maternalinterimidccversion2_2008M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M',
#   'flourish_caregiver.sociodemographicdata_2001M',
#   'flourish_caregiver.covid19_2001M',
#   'flourish_caregiver.medicalhistory_2004M',
#   'flourish_caregiver.relationshipfatherinvolvement_2004M',
#   'flourish_caregiver.relationshipfatherinvolvement_3004M',
#   'flourish_caregiver.sociodemographicdata_2002M',
#   'flourish_caregiver.covid19_2002M',
#   'flourish_caregiver.medicalhistory_2005M',
#   'flourish_caregiver.maternalinterimidccversion2_2008M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M',
#   'flourish_caregiver.sociodemographicdata_2001M',
#   'flourish_caregiver.covid19_2001M',
#   'flourish_caregiver.medicalhistory_2004M',
#   'flourish_caregiver.relationshipfatherinvolvement_2004M',
#   'flourish_caregiver.relationshipfatherinvolvement_3004M'],
#  'B142-040990639-2': ['flourish_caregiver.sociodemographicdata_1000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_1000M',
#   'flourish_caregiver.obstericalhistory_1000M',
#   'flourish_caregiver.covid19_1000M',
#   'flourish_caregiver.medicalhistory_2001M',
#   'flourish_caregiver.hivrapidtestcounseling_2000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_2000M',
#   'flourish_caregiver.covid19_2000M',
#   'flourish_caregiver.sociodemographicdata_1000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_1000M',
#   'flourish_caregiver.obstericalhistory_1000M',
#   'flourish_caregiver.covid19_1000M',
#   'flourish_caregiver.medicalhistory_2001M',
#   'flourish_caregiver.hivrapidtestcounseling_2000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_2000M',
#   'flourish_caregiver.covid19_2000M',
#   'flourish_caregiver.sociodemographicdata_1000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_1000M',
#   'flourish_caregiver.obstericalhistory_1000M',
#   'flourish_caregiver.covid19_1000M',
#   'flourish_caregiver.medicalhistory_2001M',
#   'flourish_caregiver.hivrapidtestcounseling_2000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_2000M',
#   'flourish_caregiver.covid19_2000M'],
#  'B142-040990666-5': ['flourish_caregiver.sociodemographicdata_2006M',
#   'flourish_caregiver.medicalhistory_2006M'],
#  'B142-040990357-1': ['flourish_caregiver.sociodemographicdata_2007M',
#   'flourish_caregiver.medicalhistory_2007M'],
#  'B142-040990172-4': ['flourish_caregiver.medicalhistory_2005M',
#   'flourish_caregiver.medicalhistory_3005M',
#   'flourish_caregiver.sociodemographicdata_3000C',
#   'flourish_caregiver.medicalhistory_3000C',
#   'flourish_caregiver.caregiverclinicalmeasurements_3000C',
#   'flourish_caregiver.caregiverphqdeprscreening_3000C',
#   'flourish_caregiver.caregivergadanxietyscreening_3000C',
#   'flourish_caregiver.relationshipfatherinvolvement_3000C',
#   'flourish_caregiver.sociodemographicdata_2004M',
#   'flourish_caregiver.medicalhistory_2004M',
#   'flourish_caregiver.covid19_2004M',
#   'flourish_caregiver.medicalhistory_2005M',
#   'flourish_caregiver.medicalhistory_3005M',
#   'flourish_caregiver.sociodemographicdata_3000C',
#   'flourish_caregiver.medicalhistory_3000C',
#   'flourish_caregiver.caregiverclinicalmeasurements_3000C',
#   'flourish_caregiver.caregiverphqdeprscreening_3000C',
#   'flourish_caregiver.caregivergadanxietyscreening_3000C',
#   'flourish_caregiver.relationshipfatherinvolvement_3000C',
#   'flourish_caregiver.sociodemographicdata_2004M',
#   'flourish_caregiver.medicalhistory_2004M',
#   'flourish_caregiver.covid19_2004M',
#   'flourish_caregiver.medicalhistory_2005M',
#   'flourish_caregiver.medicalhistory_3005M',
#   'flourish_caregiver.sociodemographicdata_3000C',
#   'flourish_caregiver.medicalhistory_3000C',
#   'flourish_caregiver.caregiverclinicalmeasurements_3000C',
#   'flourish_caregiver.caregiverphqdeprscreening_3000C',
#   'flourish_caregiver.caregivergadanxietyscreening_3000C',
#   'flourish_caregiver.relationshipfatherinvolvement_3000C',
#   'flourish_caregiver.sociodemographicdata_2004M',
#   'flourish_caregiver.medicalhistory_2004M',
#   'flourish_caregiver.covid19_2004M'],
#  'B142-040990096-5': ['flourish_caregiver.sociodemographicdata_3003M',
#   'flourish_caregiver.medicalhistory_3003M',
#   'flourish_caregiver.sociodemographicdata_3003M',
#   'flourish_caregiver.medicalhistory_3003M'],
#  'B142-040990651-7': ['flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M'],
#  'B142-040990023-9': ['flourish_caregiver.hivdisclosurestatusa_2007M',
#   'flourish_caregiver.sociodemographicdata_2009M'],
#  'B142-040991037-8': ['flourish_caregiver.posthivrapidtestandconseling_2004M',
#   'flourish_caregiver.sociodemographicdata_2004M',
#   'flourish_caregiver.medicalhistory_2004M',
#   'flourish_caregiver.relationshipfatherinvolvement_2004M',
#   'flourish_caregiver.sociodemographicdata_3002M',
#   'flourish_caregiver.medicalhistory_3002M'],
#  'R142-040990903-2': ['flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.covid19_2000M'],
#  'B142-040990099-9': ['flourish_caregiver.relationshipfatherinvolvement_2008M',
#   'flourish_caregiver.sociodemographicdata_2010M',
#   'flourish_caregiver.relationshipfatherinvolvement_2012M',
#   'flourish_caregiver.sociodemographicdata_2011M',
#   'flourish_caregiver.sociodemographicdata_2009M',
#   'flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_2000M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M',
#   'flourish_caregiver.sociodemographicdata_2010M',
#   'flourish_caregiver.relationshipfatherinvolvement_2012M',
#   'flourish_caregiver.sociodemographicdata_2011M',
#   'flourish_caregiver.sociodemographicdata_2009M',
#   'flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_2000M'],
#  'B142-040990369-6': ['flourish_caregiver.sociodemographicdata_2007M',
#   'flourish_caregiver.medicalhistory_2007M',
#   'flourish_caregiver.sociodemographicdata_2010M',
#   'flourish_caregiver.sociodemographicdata_2009M'],
#  'B142-040990604-6': ['flourish_caregiver.sociodemographicdata_1000M',
#   'flourish_caregiver.sociodemographicdata_2007M',
#   'flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.posthivrapidtestandconseling_2009M',
#   'flourish_caregiver.sociodemographicdata_2009M',
#   'flourish_caregiver.medicalhistory_2009M',
#   'flourish_caregiver.sociodemographicdata_1000M',
#   'flourish_caregiver.sociodemographicdata_2007M',
#   'flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.posthivrapidtestandconseling_2009M',
#   'flourish_caregiver.sociodemographicdata_2009M',
#   'flourish_caregiver.medicalhistory_2009M'],
#  'B142-040990881-0': ['flourish_caregiver.sociodemographicdata_2005M',
#   'flourish_caregiver.medicalhistory_2005M'],
#  'B142-040990120-3': ['flourish_caregiver.covid19_2005M',
#   'flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.covid19_2008M',
#   'flourish_caregiver.sociodemographicdata_2004M',
#   'flourish_caregiver.medicalhistory_2004M',
#   'flourish_caregiver.covid19_2004M'],
#  'B142-040991112-9': ['flourish_caregiver.medicalhistory_1000M',
#   'flourish_caregiver.caregiverclinicalmeasurements_1000M',
#   'flourish_caregiver.tbroutinehealthscreenv2_1000M',
#   'flourish_caregiver.covid19_1000M',
#   'flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.medicalhistory_2000M',
#   'flourish_caregiver.covid19_2000M'],
#  'B142-040990570-9': ['flourish_caregiver.medicalhistory_2005M',
#   'flourish_caregiver.sociodemographicdata_1000M',
#   'flourish_caregiver.medicalhistory_1000M',
#   'flourish_caregiver.covid19_1000M',
#   'flourish_caregiver.sociodemographicdata_2003M',
#   'flourish_caregiver.medicalhistory_2003M',
#   'flourish_caregiver.covid19_2003M',
#   'flourish_caregiver.sociodemographicdata_2006M',
#   'flourish_caregiver.medicalhistory_2005M',
#   'flourish_caregiver.sociodemographicdata_1000M',
#   'flourish_caregiver.medicalhistory_1000M',
#   'flourish_caregiver.covid19_1000M',
#   'flourish_caregiver.sociodemographicdata_2003M',
#   'flourish_caregiver.medicalhistory_2003M',
#   'flourish_caregiver.covid19_2003M',
#   'flourish_caregiver.sociodemographicdata_2006M'],
#  'B142-040990992-5': ['flourish_caregiver.sociodemographicdata_2002M',
#   'flourish_caregiver.medicalhistory_2002M',
#   'flourish_caregiver.medicalhistory_2004M'],
#  'B142-040990701-0': ['flourish_caregiver.sociodemographicdata_2006M',
#   'flourish_caregiver.medicalhistory_2006M',
#   'flourish_caregiver.maternalinterimidccversion2_2006M'],
#  'B142-040990044-5': ['flourish_caregiver.sociodemographicdata_2002M',
#   'flourish_caregiver.covid19_2002M',
#   'flourish_caregiver.sociodemographicdata_2006M',
#   'flourish_caregiver.medicalhistory_2006M'],
#  'B142-040990610-3': ['flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.maternalinterimidccversion2_2008M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M',
#   'flourish_caregiver.maternalarvpostadherence_2008M'],
#  'B142-040990705-1': ['flourish_caregiver.sociodemographicdata_2005M',
#   'flourish_caregiver.sociodemographicdata_3001M',
#   'flourish_caregiver.sociodemographicdata_2004M',
#   'flourish_caregiver.sociodemographicdata_3002M',
#   'flourish_caregiver.sociodemographicdata_2005M',
#   'flourish_caregiver.sociodemographicdata_3001M',
#   'flourish_caregiver.sociodemographicdata_2004M',
#   'flourish_caregiver.sociodemographicdata_3002M'],
#  'B142-040990645-9': ['flourish_caregiver.posthivrapidtestandconseling_2008M',
#   'flourish_caregiver.sociodemographicdata_2008M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.relationshipfatherinvolvement_2008M'],
#  'B142-040990355-5': ['flourish_caregiver.maternalinterimidccversion2_3003M'],
#  'B142-040990528-7': ['flourish_caregiver.sociodemographicdata_2003M',
#   'flourish_caregiver.medicalhistory_2003M',
#   'flourish_caregiver.covid19_2003M'],
#  'B142-040990472-8': ['flourish_caregiver.sociodemographicdata_2009M',
#   'flourish_caregiver.medicalhistory_2009M'],
#  'B142-040990612-9': ['flourish_caregiver.sociodemographicdata_2006M'],
#  'B142-040990022-1': ['flourish_caregiver.sociodemographicdata_2007M',
#   'flourish_caregiver.medicalhistory_2007M',
#   'flourish_caregiver.covid19_2007M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.sociodemographicdata_2009M'],
#  'B142-040990968-5': ['flourish_caregiver.sociodemographicdata_2002M',
#   'flourish_caregiver.covid19_2002M',
#   'flourish_caregiver.sociodemographicdata_1000M',
#   'flourish_caregiver.relationshipfatherinvolvement_1000M',
#   'flourish_caregiver.sociodemographicdata_3004M',
#   'flourish_caregiver.relationshipfatherinvolvement_3004M'],
#  'B142-040990682-2': ['flourish_caregiver.posthivrapidtestandconseling_2007M',
#   'flourish_caregiver.sociodemographicdata_2007M'],
#  'R142-040990631-9': ['flourish_caregiver.sociodemographicdata_2000M',
#   'flourish_caregiver.covid19_2000M'],
#  'B142-040990128-6': ['flourish_caregiver.sociodemographicdata_2007M',
#   'flourish_caregiver.medicalhistory_2007M',
#   'flourish_caregiver.medicalhistory_2008M',
#   'flourish_caregiver.sociodemographicdata_2010M'],
#  'B142-040990371-2': ['flourish_caregiver.sociodemographicdata_2010M',
#   'flourish_caregiver.medicalhistory_2010M']}

# %%
def format_data_to_csv(data, csv_file_path):
    # Open a new CSV file to write to
    with open(csv_file_path, mode='w', newline='') as csv_file:
        writer = csv.writer(csv_file)

        # Write headers
        writer.writerow(['Key', 'Type', 'Data'])

        # Iterate over the data and write to CSV
        for key, value in data.items():
            for item in value:
                for data_type, data_value in item.items():
                    # Transform model name to a human-readable format
                    readable_type = transform_model_name(data_type)
                    writer.writerow([key, readable_type, data_value])

# %%
format_data_to_csv(mothers_with_different_data, 'missmatch_matenal_crfs.csv')
